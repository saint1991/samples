# %%
import numpy as np
import pandas as pd

from datetime import timede

# %%
df = pd.read_csv('./datasets/netflix-stock-price.csv')

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1     2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2     2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3     2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4     2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...          ...         ...         ...         ...         ...         ...
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# 0     11896100
# ...

# %%
df.stack().reset_index(1)
# Out:
#         level_1           0
# 0          Date  2018-02-05
# 0          Open       262.0
# 0          High  267.899994
# 0           Low  250.029999
# 0         Close  254.259995
# ...         ...         ...
# 1008       High  412.769989
# 1008        Low  396.640015
# 1008      Close  410.170013
# 1008  Adj Close  410.170013
# 1008     Volume     7782400
#
# [7063 rows x 2 columns]

# %%
stack_df = df.stack().reset_index(1)
stack_df
# Out:
#         level_1           0
# 0          Date  2018-02-05
# 0          Open       262.0
# 0          High  267.899994
# 0           Low  250.029999
# 0         Close  254.259995
# ...         ...         ...
# 1008       High  412.769989
# 1008        Low  396.640015
# 1008      Close  410.170013
# 1008  Adj Close  410.170013
# 1008     Volume     7782400
#
# [7063 rows x 2 columns]

# %%
stack_df.pivot(index=None, columns='level_1', values=0)
# Out:
# level_1   Adj Close       Close        Date        High         Low  \
# 0        254.259995  254.259995  2018-02-05  267.899994  250.029999
# 1        265.720001  265.720001  2018-02-06  266.700012       245.0
# 2        264.559998  264.559998  2018-02-07  272.450012  264.329987
# 3        250.100006  250.100006  2018-02-08  267.619995       250.0
# 4        249.470001  249.470001  2018-02-09  255.800003  236.110001
# ...             ...         ...         ...         ...         ...
# 1004     427.140015  427.140015  2022-01-31  427.700012  398.200012
# 1005     457.130005  457.130005  2022-02-01  458.480011  425.540009
# 1006     429.480011  429.480011  2022-02-02  451.980011  426.480011
# 1007     405.600006  405.600006  2022-02-03   429.26001  404.279999
# 1008     410.170013  410.170013  2022-02-04  412.769989  396.640015
#
# level_1        Open    Volume
# 0             262.0  11896100
# 1        247.699997  12595800
# 2        266.579987   8981500
# ...

# %%
stack_df.columns
# Out:
# Index(['level_1', 0], dtype='object')

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
tdf = df.set_index(keys='Date')
tdf
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...                ...         ...         ...         ...         ...
# 2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#               Volume
# Date
# 2018-02-05  11896100
# 2018-02-06  12595800
# 2018-02-07   8981500
# ...

# %%
tdf.shift(2)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05         NaN         NaN         NaN         NaN         NaN
# 2018-02-06         NaN         NaN         NaN         NaN         NaN
# 2018-02-07  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-08  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-09  266.579987  272.450012  264.329987  264.559998  264.559998
# ...                ...         ...         ...         ...         ...
# 2022-01-31  382.059998  394.799988  378.100006  386.700012  386.700012
# 2022-02-01  386.760010  387.000000  372.079987  384.359985  384.359985
# 2022-02-02  401.970001  427.700012  398.200012  427.140015  427.140015
# 2022-02-03  432.959991  458.480011  425.540009  457.130005  457.130005
# 2022-02-04  448.250000  451.980011  426.480011  429.480011  429.480011
#
#                 Volume
# Date
# 2018-02-05         NaN
# 2018-02-06         NaN
# 2018-02-07  11896100.0
# ...

# %%
tdf.shift(freq=timedelta(days=-3))
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-02  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-03  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-04  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-05  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-06  253.850006  255.800003  236.110001  249.470001  249.470001
# ...                ...         ...         ...         ...         ...
# 2022-01-28  401.970001  427.700012  398.200012  427.140015  427.140015
# 2022-01-29  432.959991  458.480011  425.540009  457.130005  457.130005
# 2022-01-30  448.250000  451.980011  426.480011  429.480011  429.480011
# 2022-01-31  421.440002  429.260010  404.279999  405.600006  405.600006
# 2022-02-01  407.309998  412.769989  396.640015  410.170013  410.170013
#
#               Volume
# Date
# 2018-02-02  11896100
# 2018-02-03  12595800
# 2018-02-04   8981500
# ...

# %%
tdf
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...                ...         ...         ...         ...         ...
# 2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#               Volume
# Date
# 2018-02-05  11896100
# 2018-02-06  12595800
# 2018-02-07   8981500
# ...

# %%
tdf.shift(-3)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-06  253.850006  255.800003  236.110001  249.470001  249.470001
# 2018-02-07  252.139999  259.149994  249.000000  257.950012  257.950012
# 2018-02-08  257.290009  261.410004  254.699997  258.269989  258.269989
# 2018-02-09  260.470001  269.880005  260.329987  266.000000  266.000000
# ...                ...         ...         ...         ...         ...
# 2022-01-31  421.440002  429.260010  404.279999  405.600006  405.600006
# 2022-02-01  407.309998  412.769989  396.640015  410.170013  410.170013
# 2022-02-02         NaN         NaN         NaN         NaN         NaN
# 2022-02-03         NaN         NaN         NaN         NaN         NaN
# 2022-02-04         NaN         NaN         NaN         NaN         NaN
#
#                 Volume
# Date
# 2018-02-05   9306700.0
# 2018-02-06  16906900.0
# 2018-02-07   8534900.0
# ...

# %%
tdf.rolling(window=3, center=True).sum()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-02-05          NaN          NaN          NaN          NaN          NaN
# 2018-02-06   776.279984   807.050018   759.359986   784.539994   784.539994
# 2018-02-07   781.359971   806.770019   759.329987   780.380005   780.380005
# 2018-02-08   787.509980   795.870010   750.439988   764.130005   764.130005
# 2018-02-09   773.069992   782.569992   735.110001   757.520019   757.520019
# ...                 ...          ...          ...          ...          ...
# 2022-01-31  1221.690002  1273.180023  1195.820008  1268.630005  1268.630005
# 2022-02-01  1283.179992  1338.160034  1250.220032  1313.750031  1313.750031
# 2022-02-02  1302.649993  1339.720032  1256.300019  1292.210022  1292.210022
# 2022-02-03  1277.000000  1294.010010  1227.400025  1245.250030  1245.250030
# 2022-02-04          NaN          NaN          NaN          NaN          NaN
#
#                 Volume
# Date
# ...

# %%
262 + 248 + 266.5
# Out:
# 776.5

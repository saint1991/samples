# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./datasets/titanic.csv')

# %%
df['Embarked'] = df['Embarked'] == 'S'

# %%
df['Embarked'].replace({True: 1, False: 0}, inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# ## DataFrame#map

# %%
test_df = df.copy()

# %%
test_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
target_mean = df.groupby('Sex')['Embarked'].mean()
target_mean
# Out:
# Sex
# female    0.578947
# male      0.684211
# Name: Embarked, dtype: float64

# %%
test_df['Sex'].map(target_mean)
# Out:
# 0      0.684211
# 1      0.578947
# 2      0.684211
# 3      0.684211
# 4      0.578947
#          ...
# 413    0.684211
# 414    0.578947
# 415    0.684211
# 416    0.684211
# 417    0.684211
# Name: Sex, Length: 418, dtype: float64

# %% [markdown]
# ## KFold

# %%
from sklearn.model_selection import KFold

# %%
kf = KFold(n_splits=4, shuffle=True, random_state=72)

# %%
tmp = np.repeat(np.nan, df.shape[0])
tmp
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
# ...

# %%
for idx_1, idx_2 in kf.split(df):
    target_mean = df.iloc[idx_1].groupby("Sex")['Embarked'].mean()
    tmp[idx_2] = df["Sex"].iloc[idx_2].map(target_mean)

# %%
df["Sex"] = tmp

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name       Sex   Age  SibSp  \
# 0                                Kelly, Mr. James  0.658163  34.5      0
# 1                Wilkes, Mrs. James (Ellen Needs)  0.581197  47.0      1
# 2                       Myles, Mr. Thomas Francis  0.689655  62.0      0
# 3                                Wirz, Mr. Albert  0.658163  27.0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  0.594595  22.0      1
# ..                                            ...       ...   ...    ...
# ...
